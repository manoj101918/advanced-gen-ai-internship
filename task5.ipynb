# %% [markdown]
# <a href="https://colab.research.google.com/github/manoj101918/advanced-gen-ai-internship/blob/main/task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Social Media – Post Engagement Analyzer

# %%
def analyze_engagement(likes_list):
    total_likes = 0

    # Loop to calculate total likes
    for like in likes_list:
        total_likes += like

    print("Total Likes:", total_likes)

    # Condition check
    if total_likes >= 1000:
        print("Post Status: Viral Post")
    else:
        print("Post Status: Normal Engagement")

# %% [markdown]
# Problem 2: Healthcare – Medicine Stock Alert System

# %%
def check_medicine_stock(stock):

    print("Medicine Stock:", stock)

    if stock < 10:
        print("Status: Low Stock Alert")
    else:
        print("Status: Stock Sufficient")

# %% [markdown]
# Problem 3: Agriculture – Rainfall Adequacy Checker

# %%
def analyze_rainfall(rainfall_data, required_level):
    total_rainfall = 0

    # Loop to calculate total rainfall
    for rain in rainfall_data:
        total_rainfall += rain

    # Calculate average
    average_rainfall = total_rainfall / len(rainfall_data)

    print("Average Rainfall:", int(average_rainfall))

    # Condition check
    if average_rainfall >= required_level:
        print("Rainfall Status: Adequate Rainfall")
    else:
        print("Rainfall Status: Inadequate Rainfall")

# %% [markdown]
# Problem 4: Social Media – Duplicate Account Detection

# %%
def detect_duplicate_usernames(usernames):
    unique_users = set()
    duplicate_found = False

    for username in usernames:
        if username in unique_users:
            duplicate_found = True
            break
        unique_users.add(username)

    if duplicate_found:
        print("Duplicate Accounts Found: Yes")
    else:
        print("Duplicate Accounts Found: No")

# %% [markdown]
# Problem 5: Healthcare – Appointment Eligibility Checker

# %%
def check_appointment_eligibility(age):

    print("Patient Age:", age)

    if age >= 18:
        print("Eligibility Status: Eligible")
    else:
        print("Eligibility Status: Not Eligible")

# %% [markdown]
# Problem 6: Agriculture – Premium Crop Price Filter

# %%
def filter_premium_crops(prices):
    premium_crops = []

    for price in prices:
        if price > 2000:
            premium_crops.append(price)

    print("Premium Crops:", premium_crops)
